# %% [markdown]
# # Import library and data loading

# %%
import pandas as pd

# %%
df=pd.read_csv('covid_19_indonesia_time_series_all.csv')

# %%
df
# Out:
#             Date Location ISO Code          Location  New Cases  New Deaths  \
# 0       3/1/2020             ID-JK       DKI Jakarta          2           0
# 1       3/2/2020             ID-JK       DKI Jakarta          2           0
# 2       3/2/2020               IDN         Indonesia          2           0
# 3       3/2/2020             ID-RI              Riau          1           0
# 4       3/3/2020             ID-JK       DKI Jakarta          2           0
# ...          ...               ...               ...        ...         ...
# 21754  12/2/2021             ID-SA    Sulawesi Utara          2           0
# 21755  12/2/2021             ID-SB    Sumatera Barat          4           0
# 21756  12/2/2021             ID-SS  Sumatera Selatan          4           0
# 21757  12/2/2021             ID-SU    Sumatera Utara          4           0
# 21758  12/3/2021               IDN         Indonesia        245           8
#
#        New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0                  0                 2           39            20
# 1                  0                 2           41            20
# 2                  0                 2            2             0
# 3                  0                 1            2             0
# 4                  0                 2           43            20
# ...              ...               ...          ...           ...
# 21754              0                 2        34715          1056
# 21755              0                 4        89849          2152
# 21756              0                 4        59937          3071
# 21757              1                 3       106045          2889
# 21758            328               -91      4257243        143858
#
#        Total Recovered  ...  Latitude New Cases per Million  \
# 0                   41  ... -6.204699                  0.18
# 1                   41  ... -6.204699                  0.18
# 2                    0  ... -0.789275                  0.01
# 3                    3  ...  0.511648                  0.16
# 4                   41  ... -6.204699                  0.18
# ...                ...  ...       ...                   ...
# 21754            33566  ...  1.259638                  0.76
# 21755            87605  ... -0.850253                  0.72
# 21756            56830  ... -3.216212                  0.49
# 21757           103061  ...  2.191894                  0.27
# 21758          4105680  ... -0.789275                  0.92
#
#        Total Cases per Million New Deaths per Million  \
# 0                         3.60                   0.00
# 1                         3.78                   0.00
# 2                         0.01                   0.00
# 3                         0.33                   0.00
# 4                         3.96                   0.00
# ...                        ...                    ...
# 21754                 13140.24                   0.00
# 21755                 16279.22                   0.00
# 21756                  7293.78                   0.00
# 21757                  7129.13                   0.00
# 21758                 16053.83                   0.03
#
#       Total Deaths per Million Total Deaths per 100rb Case Fatality Rate  \
# 0                         1.84                   0.18             51.28%
# 1                         1.84                   0.18             48.78%
# 2                         0.00                   0.00              0.00%
# 3                         0.00                   0.00              0.00%
# 4                         1.84                   0.18             46.51%
# ...                        ...                    ...                ...
# 21754                   399.71                  39.97              3.04%
# 21755                   389.91                  38.99              2.40%
# 21756                   373.71                  37.37              5.12%
# 21757                   194.22                  19.42              2.72%
# 21758                   542.48                  54.25              3.38%
#
#       Case Recovered Rate Growth Factor of New Cases  \
# 0                 105.13%                        NaN
# 1                 100.00%                       1.00
# 2                   0.00%                        NaN
# 3                 150.00%                        NaN
# 4                  95.35%                       1.00
# ...                   ...                        ...
# 21754              96.69%                        NaN
# 21755              97.50%                       4.00
# 21756              94.82%                       4.00
# 21757              97.19%                       1.00
# 21758              96.44%                       0.79
#
#        Growth Factor of New Deaths
# 0                              NaN
# 1                              1.0
# 2                              NaN
# 3                              NaN
# 4                              1.0
# ...                            ...
# 21754                          1.0
# 21755                          1.0
# 21756                          1.0
# 21757                          1.0
# 21758                          0.8
#
# [21759 rows x 38 columns]

# %% [markdown]
# # Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21759 entries, 0 to 21758
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         21759 non-null  object
#  1   Location ISO Code            21759 non-null  object
#  2   Location                     21759 non-null  object
#  3   New Cases                    21759 non-null  int64
#  4   New Deaths                   21759 non-null  int64
#  5   New Recovered                21759 non-null  int64
#  6   New Active Cases             21759 non-null  int64
#  7   Total Cases                  21759 non-null  int64
#  8   Total Deaths                 21759 non-null  int64
#  9   Total Recovered              21759 non-null  int64
#  10  Total Active Cases           21759 non-null  int64
#  11  Location Level               21759 non-null  object
#  12  City or Regency              0 non-null      float64
#  13  Province                     21117 non-null  object
#  14  Country                      21759 non-null  object
#  15  Continent                    21759 non-null  object
#  16  Island                       21117 non-null  object
#  17  Time Zone                    21117 non-null  object
#  18  Special Status               3123 non-null   object
#  19  Total Regencies              21759 non-null  int64
#  20  Total Cities                 21145 non-null  float64
#  21  Total Districts              21759 non-null  int64
#  22  Total Urban Villages         21142 non-null  float64
#  23  Total Rural Villages         21117 non-null  float64
#  24  Area (km2)                   21759 non-null  int64
#  25  Population                   21759 non-null  int64
#  26  Population Density           21759 non-null  float64
#  27  Longitude                    21759 non-null  float64
#  28  Latitude                     21759 non-null  float64
#  29  New Cases per Million        21759 non-null  float64
#  30  Total Cases per Million      21759 non-null  float64
#  31  New Deaths per Million       21759 non-null  float64
#  32  Total Deaths per Million     21759 non-null  float64
#  33  Total Deaths per 100rb       21759 non-null  float64
#  34  Case Fatality Rate           21759 non-null  object
#  35  Case Recovered Rate          21759 non-null  object
#  36  Growth Factor of New Cases   20572 non-null  float64
#  37  Growth Factor of New Deaths  19292 non-null  float64
# dtypes: float64(14), int64(12), object(12)
# memory usage: 6.3+ MB

# %%
df.isna().sum()
# Out:
# Date                               0
# Location ISO Code                  0
# Location                           0
# New Cases                          0
# New Deaths                         0
# New Recovered                      0
# New Active Cases                   0
# Total Cases                        0
# Total Deaths                       0
# Total Recovered                    0
# Total Active Cases                 0
# Location Level                     0
# City or Regency                21759
# Province                         642
# Country                            0
# Continent                          0
# Island                           642
# Time Zone                        642
# Special Status                 18636
# Total Regencies                    0
# Total Cities                     614
# Total Districts                    0
# Total Urban Villages             617
# Total Rural Villages             642
# Area (km2)                         0
# Population                         0
# Population Density                 0
# Longitude                          0
# Latitude                           0
# New Cases per Million              0
# Total Cases per Million            0
# New Deaths per Million             0
# Total Deaths per Million           0
# Total Deaths per 100rb             0
# Case Fatality Rate                 0
# Case Recovered Rate                0
# Growth Factor of New Cases      1187
# Growth Factor of New Deaths     2467
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Location ISO Code', 'Location', 'New Cases', 'New Deaths',
#        'New Recovered', 'New Active Cases', 'Total Cases', 'Total Deaths',
#        'Total Recovered', 'Total Active Cases', 'Location Level',
#        'City or Regency', 'Province', 'Country', 'Continent', 'Island',
#        'Time Zone', 'Special Status', 'Total Regencies', 'Total Cities',
#        'Total Districts', 'Total Urban Villages', 'Total Rural Villages',
#        'Area (km2)', 'Population', 'Population Density', 'Longitude',
#        'Latitude', 'New Cases per Million', 'Total Cases per Million',
#        'New Deaths per Million', 'Total Deaths per Million',
#        'Total Deaths per 100rb', 'Case Fatality Rate', 'Case Recovered Rate',
#        'Growth Factor of New Cases', 'Growth Factor of New Deaths'],
#       dtype='object')

# %%
dfc=df.copy().drop(columns=['Special Status','City or Regency'])

# %%
dfc=dfc.dropna()

# %%
dfc
# Out:
#             Date Location ISO Code          Location  New Cases  New Deaths  \
# 7       3/3/2020             ID-RI              Riau          0           0
# 10      3/4/2020             ID-JB        Jawa Barat          1           0
# 11      3/4/2020             ID-RI              Riau          0           0
# 14      3/5/2020             ID-JB        Jawa Barat          1           0
# 15      3/5/2020             ID-RI              Riau          0           0
# ...          ...               ...               ...        ...         ...
# 21750  12/2/2021             ID-RI              Riau          4           0
# 21752  12/2/2021             ID-ST   Sulawesi Tengah         11           0
# 21755  12/2/2021             ID-SB    Sumatera Barat          4           0
# 21756  12/2/2021             ID-SS  Sumatera Selatan          4           0
# 21757  12/2/2021             ID-SU    Sumatera Utara          4           0
#
#        New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 7                  0                 0            2             0
# 10                 0                 1            2             1
# 11                 0                 0            2             0
# 14                 0                 1            3             1
# 15                 0                 0            2             0
# ...              ...               ...          ...           ...
# 21750              0                 4       128825          4109
# 21752              2                 9        47153          1602
# 21755              0                 4        89849          2152
# 21756              0                 4        59937          3071
# 21757              1                 3       106045          2889
#
#        Total Recovered  ...  Latitude New Cases per Million  \
# 7                    3  ...  0.511648                  0.00
# 10                   8  ... -6.920432                  0.02
# 11                   3  ...  0.511648                  0.00
# 14                   8  ... -6.920432                  0.02
# 15                   3  ...  0.511648                  0.00
# ...                ...  ...       ...                   ...
# 21750           124123  ...  0.511648                  0.66
# 21752            45503  ... -1.004137                  3.72
# 21755            87605  ... -0.850253                  0.72
# 21756            56830  ... -3.216212                  0.49
# 21757           103061  ...  2.191894                  0.27
#
#       Total Cases per Million New Deaths per Million Total Deaths per Million  \
# 7                        0.33                    0.0                     0.00
# 10                       0.04                    0.0                     0.02
# 11                       0.33                    0.0                     0.00
# 14                       0.07                    0.0                     0.02
# 15                       0.33                    0.0                     0.00
# ...                       ...                    ...                      ...
# 21750                21208.90                    0.0                   676.48
# 21752                15953.96                    0.0                   542.03
# 21755                16279.22                    0.0                   389.91
# 21756                 7293.78                    0.0                   373.71
# 21757                 7129.13                    0.0                   194.22
#
#       Total Deaths per 100rb Case Fatality Rate  Case Recovered Rate  \
# 7                       0.00              0.00%              150.00%
# 10                      0.00             50.00%              400.00%
# 11                      0.00              0.00%              150.00%
# 14                      0.00             33.33%              266.67%
# 15                      0.00              0.00%              150.00%
# ...                      ...                ...                  ...
# 21750                  67.65              3.19%               96.35%
# 21752                  54.20              3.40%               96.50%
# 21755                  38.99              2.40%               97.50%
# 21756                  37.37              5.12%               94.82%
# 21757                  19.42              2.72%               97.19%
#
#        Growth Factor of New Cases  Growth Factor of New Deaths
# 7                             0.0                          1.0
# 10                            1.0                          0.0
# 11                            1.0                          1.0
# 14                            1.0                          1.0
# 15                            1.0                          1.0
# ...                           ...                          ...
# 21750                         0.5                          1.0
# 21752                         2.2                          1.0
# 21755                         4.0                          1.0
# 21756                         4.0                          1.0
# 21757                         1.0                          1.0
#
# [16051 rows x 36 columns]

# %% [markdown]
# # Central Tendency

# %%
dfc.mean()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_8280/1063878094.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dfc.mean()
# New Cases                      2.003300e+02
# New Deaths                     7.652296e+00
# New Recovered                  1.923823e+02
# New Active Cases               2.953710e-01
# Total Cases                    4.091619e+04
# Total Deaths                   1.470059e+03
# Total Recovered                3.620721e+04
# Total Active Cases             3.238919e+03
# Total Regencies                1.287085e+01
# Total Cities                   2.975702e+00
# Total Districts                2.282820e+02
# Total Urban Villages           2.749885e+02
# Total Rural Villages           2.288301e+03
# Area (km2)                     5.912457e+04
# Population                     8.683966e+06
# Population Density             3.056756e+02
# Longitude                      1.139153e+02
# Latitude                      -3.019576e+00
# New Cases per Million          2.998295e+01
# Total Cases per Million        5.946540e+03
# New Deaths per Million         8.880836e-01
# Total Deaths per Million       1.674268e+02
# Total Deaths per 100rb         1.674266e+01
# Growth Factor of New Cases     1.326018e+00
# Growth Factor of New Deaths    1.082515e+00
# dtype: float64

# %%
dfc.median()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_8280/3476534310.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dfc.median()
# New Cases                      4.600000e+01
# New Deaths                     1.000000e+00
# New Recovered                  3.600000e+01
# New Active Cases               0.000000e+00
# Total Cases                    1.203800e+04
# Total Deaths                   3.140000e+02
# Total Recovered                1.007500e+04
# Total Active Cases             9.910000e+02
# Total Regencies                1.100000e+01
# Total Cities                   2.000000e+00
# Total Districts                1.690000e+02
# Total Urban Villages           1.750000e+02
# Total Rural Villages           1.507000e+03
# Area (km2)                     4.201300e+04
# Population                     4.216171e+06
# Population Density             1.038400e+02
# Longitude                      1.127329e+02
# Latitude                      -2.993595e+00
# New Cases per Million          8.770000e+00
# Total Cases per Million        3.015130e+03
# New Deaths per Million         7.000000e-02
# Total Deaths per Million       7.859000e+01
# Total Deaths per 100rb         7.860000e+00
# Growth Factor of New Cases     9.900000e-01
# Growth Factor of New Deaths    1.000000e+00
# dtype: float64

# %%
dfc.describe()
# Out:
#           New Cases    New Deaths  New Recovered  New Active Cases  \
# count  16051.000000  16051.000000   16051.000000      16051.000000
# mean     200.330011      7.652296     192.382344          0.295371
# std      575.065517     29.434585     588.454435        379.145909
# min        0.000000      0.000000       0.000000     -15797.000000
# 25%        8.000000      0.000000       5.000000        -18.000000
# 50%       46.000000      1.000000      36.000000          0.000000
# 75%      156.000000      5.000000     150.000000         27.000000
# max    10678.000000    544.000000   18555.000000       6021.000000
#
#          Total Cases  Total Deaths  Total Recovered  Total Active Cases  \
# count   16051.000000  16051.000000     16051.000000        16051.000000
# mean    40916.191764   1470.059498     36207.213009         3238.919257
# std     89328.399022   3986.004287     81863.888606         8163.561484
# min         1.000000      0.000000         0.000000        -2306.000000
# 25%      2245.500000     64.000000      1339.500000          213.000000
# 50%     12038.000000    314.000000     10075.000000          991.000000
# 75%     37151.000000   1048.000000     33390.500000         2583.500000
# max    707934.000000  30225.000000    692101.000000       118018.000000
#
#        Total Regencies  Total Cities  ...  Population Density     Longitude  \
# count     16051.000000  16051.000000  ...        16051.000000  16051.000000
# mean         12.870849      2.975702  ...          305.675598    113.915310
# std           7.453420      2.492462  ...          401.750434      9.776472
# min           4.000000      1.000000  ...            8.590000     99.051964
# 25%           8.000000      1.000000  ...           47.790000    106.109004
# 50%          11.000000      2.000000  ...          103.840000    112.732941
# 75%          15.000000      4.000000  ...          262.700000    121.201093
# max          29.000000      9.000000  ...         1276.550000    138.696030
#
#            Latitude  New Cases per Million  Total Cases per Million  \
# count  16051.000000           16051.000000             16051.000000
# mean      -3.019576              29.982949              5946.540445
# std        3.575033              65.687053              8510.465347
# min       -8.682205               0.000000                 0.030000
# 25%       -6.456736               1.970000               513.525000
# 50%       -2.993595               8.770000              3015.130000
# 75%        0.212037              27.845000              7648.120000
# max        3.916346             974.700000             55343.330000
#
#        New Deaths per Million  Total Deaths per Million  \
# count            16051.000000              16051.000000
# mean                 0.888084                167.426780
# std                  2.457154                253.668747
# min                  0.000000                  0.000000
# 25%                  0.000000                 14.040000
# 50%                  0.070000                 78.590000
# 75%                  0.730000                202.625000
# max                 63.800000               1533.980000
#
#        Total Deaths per 100rb  Growth Factor of New Cases  \
# count            16051.000000                16051.000000
# mean                16.742665                    1.326018
# std                 25.366931                    2.337142
# min                  0.000000                    0.000000
# 25%                  1.400000                    0.630000
# 50%                  7.860000                    0.990000
# 75%                 20.260000                    1.310000
# max                153.400000                   91.000000
#
#        Growth Factor of New Deaths
# count                 16051.000000
# mean                      1.082515
# std                       1.691408
# min                       0.000000
# 25%                       0.560000
# 50%                       1.000000
# 75%                       1.000000
# max                     134.500000
#
# [8 rows x 25 columns]

# %% [markdown]
# # Measure of Variance

# %%
dfc.var()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_8280/2317592042.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dfc.var()
# New Cases                      3.307003e+05
# New Deaths                     8.663948e+02
# New Recovered                  3.462786e+05
# New Active Cases               1.437516e+05
# Total Cases                    7.979563e+09
# Total Deaths                   1.588823e+07
# Total Recovered                6.701696e+09
# Total Active Cases             6.664374e+07
# Total Regencies                5.555347e+01
# Total Cities                   6.212369e+00
# Total Districts                3.165923e+04
# Total Urban Villages           5.501215e+04
# Total Rural Villages           4.372986e+06
# Area (km2)                     3.667267e+09
# Population                     1.410036e+14
# Population Density             1.614034e+05
# Longitude                      9.557941e+01
# Latitude                       1.278086e+01
# New Cases per Million          4.314789e+03
# Total Cases per Million        7.242802e+07
# New Deaths per Million         6.037607e+00
# Total Deaths per Million       6.434783e+04
# Total Deaths per 100rb         6.434812e+02
# Growth Factor of New Cases     5.462231e+00
# Growth Factor of New Deaths    2.860862e+00
# dtype: float64

# %%
dfc.std()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_8280/3389852736.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dfc.std()
# New Cases                      5.750655e+02
# New Deaths                     2.943459e+01
# New Recovered                  5.884544e+02
# New Active Cases               3.791459e+02
# Total Cases                    8.932840e+04
# Total Deaths                   3.986004e+03
# Total Recovered                8.186389e+04
# Total Active Cases             8.163561e+03
# Total Regencies                7.453420e+00
# Total Cities                   2.492462e+00
# Total Districts                1.779304e+02
# Total Urban Villages           2.345467e+02
# Total Rural Villages           2.091169e+03
# Area (km2)                     6.055796e+04
# Population                     1.187450e+07
# Population Density             4.017504e+02
# Longitude                      9.776472e+00
# Latitude                       3.575033e+00
# New Cases per Million          6.568705e+01
# Total Cases per Million        8.510465e+03
# New Deaths per Million         2.457154e+00
# Total Deaths per Million       2.536687e+02
# Total Deaths per 100rb         2.536693e+01
# Growth Factor of New Cases     2.337142e+00
# Growth Factor of New Deaths    1.691408e+00
# dtype: float64
